# %% [markdown]
# <a href="https://colab.research.google.com/github/bpupadhyaya/PythonVisualization/blob/master/hm1_bu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from vega_datasets import data
movies_data = data.movies()
movies_data.head()
# Out:
#                         Title   US_Gross  ...  IMDB_Rating  IMDB_Votes
# 0              The Land Girls   146083.0  ...          6.1      1071.0
# 1      First Love, Last Rites    10876.0  ...          6.9       207.0
# 2  I Married a Strange Person   203134.0  ...          6.8       865.0
# 3        Let's Talk About Sex   373615.0  ...          NaN         NaN
# 4                        Slam  1009819.0  ...          3.4       165.0
#
# [5 rows x 16 columns]

# %%
from vega_datasets import data
movies_data = data.movies()
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="Production_Budget",y="US_DVD_Sales",hue="Major_Genre",  data=movies_data,)
plt.title("Production Budget Vs. US DVD Sales - Genre")
plt.xlabel("Production Budget")
plt.ylabel("US DVD Sales")
plt.show()
